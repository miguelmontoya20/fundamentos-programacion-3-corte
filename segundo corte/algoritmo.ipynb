# %%
import pandas as pd

# %%
notasemillero=pd.DataFrame({'Nombres':['pedro','leidy','juan','sofia','camila','cristian','photer','julian','miguel','carlos'],
                            'semestre':[10,9,7,5,6,3,2,9,6,7],
                            'edad':[6,7,8,9,7,4,6,7,4,6]})
print(notasemillero)
# Out:
#     Nombres  semestre  edad
# 0     pedro        10     6
# 1     leidy         9     7
# 2      juan         7     8
# 3     sofia         5     9
# 4    camila         6     7
# 5  cristian         3     4
# 6    photer         2     6
# 7    julian         9     7
# 8    miguel         6     4
# 9    carlos         7     6

# %%
notasemillero['Nota 2']=[3.1,4.3,5,2.9,5,3.1,4,5,2.9,2.1]
notasemillero
# Out:
#     Nombres  semestre  edad  Nota 2
# 0     pedro        10     6     3.1
# 1     leidy         9     7     4.3
# 2      juan         7     8     5.0
# 3     sofia         5     9     2.9
# 4    camila         6     7     5.0
# 5  cristian         3     4     3.1
# 6    photer         2     6     4.0
# 7    julian         9     7     5.0
# 8    miguel         6     4     2.9
# 9    carlos         7     6     2.1

# %%
notasemillero['Nota 1']=3
notasemillero
# Out:
#     Nombres  semestre  edad  Nota 2  Nota 1
# 0     pedro        10     6     3.1       3
# 1     leidy         9     7     4.3       3
# 2      juan         7     8     5.0       3
# 3     sofia         5     9     2.9       3
# 4    camila         6     7     5.0       3
# 5  cristian         3     4     3.1       3
# 6    photer         2     6     4.0       3
# 7    julian         9     7     5.0       3
# 8    miguel         6     4     2.9       3
# 9    carlos         7     6     2.1       3

# %%
notasemillero['ciudad']='Manizales','Neira','Aranzazu','Bogota','cali','medellin','amazonas','aguadas','filadelfia','popayan'
notasemillero
# Out:
#     Nombres  semestre  edad  Nota 2  Nota 1      nota 3      ciudad  \
# 0     pedro        10     6     3.1       3   Manizales   Manizales
# 1     leidy         9     7     4.3       3       Neira       Neira
# 2      juan         7     8     5.0       3    Aranzazu    Aranzazu
# 3     sofia         5     9     2.9       3      Bogota      Bogota
# 4    camila         6     7     5.0       3        cali        cali
# 5  cristian         3     4     3.1       3    medellin    medellin
# 6    photer         2     6     4.0       3    amazonas    amazonas
# 7    julian         9     7     5.0       3     aguadas     aguadas
# 8    miguel         6     4     2.9       3  filadelfia  filadelfia
# 9    carlos         7     6     2.1       3     popayan     popayan
#
#   Departamentos, capitales Departamentos y Capitales Departamentos_Capitales
# 0                   caldas                    caldas                  caldas
# ...

# %%
notasemillero['Departamentos,Capitales']='caldas','caldas','caldas','cundinamarca','valle del cauca','antioquia','leticia','caldas','caldas','mocoa'
notasemillero
# Out:
#     Nombres  semestre  edad  Nota 2  Nota 1      nota 3      ciudad  \
# 0     pedro        10     6     3.1       3   Manizales   Manizales
# 1     leidy         9     7     4.3       3       Neira       Neira
# 2      juan         7     8     5.0       3    Aranzazu    Aranzazu
# 3     sofia         5     9     2.9       3      Bogota      Bogota
# 4    camila         6     7     5.0       3        cali        cali
# 5  cristian         3     4     3.1       3    medellin    medellin
# 6    photer         2     6     4.0       3    amazonas    amazonas
# 7    julian         9     7     5.0       3     aguadas     aguadas
# 8    miguel         6     4     2.9       3  filadelfia  filadelfia
# 9    carlos         7     6     2.1       3     popayan     popayan
#
#   Departamentos, capitales Departamentos y Capitales Departamentos_Capitales  \
# 0                   caldas                    caldas                  caldas
# ...
